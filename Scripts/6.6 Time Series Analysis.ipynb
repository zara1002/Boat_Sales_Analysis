# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import warnings 

# Setting up Quandl API key
quandl.ApiConfig.api_key = 'xMam6jQGZFzhYNWK2pCC'

warnings.filterwarnings("ignore") 

plt.style.use('fivethirtyeight')

# %%
path = r'/Users/aislingm/Documents/Achievement 6'

# %%
#import data set
df = pd.read_csv(os.path.join(path, '6.6', 'Data', '64_boat_data.csv'))

# %%
#check shape of data
df.shape
# Out:
# (9238, 5)

# %%
print(df.head())
# Out:
#    Year Built  Price_Eur  Length  Width  N. views last 7d
# 0        1992    14304.0    7.70   2.46              3263
# 1        1979    33600.0   11.12   3.88              2432
# 2        2002   120864.0   12.35   3.48              2261
# 3        2009   949000.0   20.30   5.20              2154
# 4        1993    19104.0    6.14   2.34              2026

# %%
# Create a new DataFrame with only 'Built Year' and 'Price_Eur'
new_df = df[['Year Built', 'Price_Eur']].copy()

# Display the new DataFrame
print(new_df.head())
# Out:
#    Year Built  Price_Eur
# 0        1992    14304.0
# 1        1979    33600.0
# 2        2002   120864.0
# 3        2009   949000.0
# 4        1993    19104.0

# %%
# Reset and drop Index column
new_df.reset_index(drop=True, inplace=True)

# Display column names and types
print(new_df.dtypes)
# Out:
# Year Built      int64
# Price_Eur     float64
# dtype: object

# %%
#check shape of data
new_df.shape
# Out:
# (9238, 2)

# %%
new_df.columns
# Out:
# Index(['Year Built', 'Price_Eur'], dtype='object')

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Plot the data using matplotlib.

plt.plot(new_df['Year Built'], new_df['Price_Eur'], marker='o', linestyle='-', color='b', label='Boat Value')

# Setting labels and title
plt.title("Year Built vs Boat value in Euro")
plt.xlabel("Year Built")
plt.ylabel("Boat value")

# Display a legend
plt.legend()

# Adjust x-axis ticks for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
